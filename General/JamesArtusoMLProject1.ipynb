# %% [markdown]
# # James Artuso
# # Programming Exercise \#1
# ---

# %% [markdown]
# # Preamble

# %%
# import relevant Python libraries

import pandas as pd
import numpy as np
from scipy import stats as sps
from IPython.display import display, Latex

# %% [markdown]
# # **1. Fetal Health Classification Dataset**

# %% [markdown]
# ## **Clean Dataset**

# %% [markdown]
# ### Problem 1.1

# %%
# load the clean dataset csv file into a pandas dataframe
fetal_df = pd.read_csv('fetal_health_dataset_clean.csv')

# %% [markdown]
# #### (a)

# %% [markdown]
# This is a supervised learning task because it has both dependent and independet features in the data set.

# %% [markdown]
# #### (b)

# %%
fetal_df.axes
fetal_df.dtypes
# Out:
# baseline value                                              int64
# accelerations                                             float64
# fetal_movement                                            float64
# uterine_contractions                                      float64
# light_decelerations                                       float64
# severe_decelerations                                      float64
# prolongued_decelerations                                  float64
# abnormal_short_term_variability                             int64
# mean_value_of_short_term_variability                      float64
# percentage_of_time_with_abnormal_long_term_variability      int64
# mean_value_of_long_term_variability                       float64
# histogram_width                                             int64
# histogram_min                                               int64
# histogram_max                                               int64
# ...

# %% [markdown]
# #### (c)

# %%
fetal_df.head(10)
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0             120          0.000             0.0                 0.000
# 1             132          0.006             0.0                 0.006
# 2             133          0.003             0.0                 0.008
# 3             134          0.003             0.0                 0.008
# 4             132          0.007             0.0                 0.008
# 5             134          0.001             0.0                 0.010
# 6             134          0.001             0.0                 0.013
# 7             122          0.000             0.0                 0.000
# 8             122          0.000             0.0                 0.002
# 9             122          0.000             0.0                 0.003
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                     0.000
# ...

# %% [markdown]
# #### (d)

# %%
print('{} Rows\n{} Columns'.format(*fetal_df.shape))
# Out:
# 2126 Rows
# 22 Columns

# %% [markdown]
# #### (e)

# %% [markdown]
# Each row is a different data sample.

# %% [markdown]
# #### (f)

# %% [markdown]
# The total number of samples is 2126 data samples

# %% [markdown]
# #### (g)

# %% [markdown]
# There are 21 independent features. These are
#
#
#
# *   Baseline Value
# *   Accelerations
# *   fetal_movement
# *   Uterine_contractions
# *   light_decelerations
# *   Severe_decelerations
# *   prolongued_decelerations
# *   Abnormal_short_term_variablility
# *   Mean_Value_of_short_term_variability
# *   Percentage_of_time_with_abnormal_long_term_variability
# *   Mean_value_of_long_term_variability
# *   histogram_width
# *   histogram_min
# *   histogram_max
# *   histogram_number_of_peaks
# *   histogram_number_of_zeros
# *   histogram_mode
# *   histogram_mean
# *   histogram_median
# *   histogram_variance
# *   histogram_tendency

# %% [markdown]
# #### (h)

# %% [markdown]
# There is one dependent variable in this data set. It is fetal_health

# %% [markdown]
# #### (i)

# %% [markdown]
# In this case, n = 2126 and p = 21

# %% [markdown]
# #### (j)

# %% [markdown]
# In this case, n = 2126 and m = 1

# %% [markdown]
# #### (k)

# %% [markdown]
# Some of these variables have been preprocess. For example, the histogram values are calculated based on other data. The other data is processed in a way to give rise to the histogram data. In other cases, baseline_value for example, the data is 'raw'. There is no transformation to change the data into something new.

# %% [markdown]
# #### (l)

# %%
for col in fetal_df:
  print(col, end = " ") 
  print(str(pd.unique(fetal_df[col])))

fetal_df.hist(figsize = [15,15])
# Out:
# baseline value [120 132 133 134 122 151 150 131 130 129 128 124 115 114 116 158 156 148
#  149 146 144 142 136 141 138 140 154 145 139 125 123 159 143 119 121 127
#  126 118 135 137 147 157 117 152 112 106 110 160]
# accelerations [0.    0.006 0.003 0.007 0.001 0.005 0.009 0.002 0.008 0.004 0.01  0.015
#  0.013 0.014 0.011 0.017 0.012 0.016 0.019 0.018]
# fetal_movement [0.    0.072 0.222 0.408 0.38  0.441 0.383 0.451 0.469 0.34  0.425 0.334
#  0.135 0.099 0.108 0.112 0.089 0.103 0.085 0.109 0.079 0.065 0.055 0.058
#  0.047 0.038 0.012 0.018 0.02  0.005 0.003 0.006 0.001 0.004 0.009 0.01
#  0.002 0.008 0.007 0.028 0.026 0.107 0.013 0.016 0.029 0.05  0.053 0.011
#  0.015 0.022 0.021 0.017 0.019 0.025 0.014 0.024 0.023 0.035 0.054 0.03
#  0.048 0.088 0.043 0.052 0.091 0.033 0.092 0.084 0.115 0.041 0.04  0.027
#  0.031 0.063 0.06  0.071 0.306 0.298 0.139 0.189 0.157 0.235 0.36  0.455
#  0.443 0.47  0.477 0.446 0.481 0.369 0.335 0.43  0.346 0.323 0.375 0.353
# ...

# %% [markdown]
# There are 2 categorical variables in this dataset. They are
#
# *   histogram_tendency
#   This is categorical because it is saying wether the histogram is left, center, or right leaning. There is no continuous measurement, just simplified down to -1, 0, 1
# *   fetal_health
#   This is categorical because it is saying whether the fetus is healthy or not.
#
# One feature that appears categorical but is not is severe_decelerations. This value is not categorical because it is a measurement. It just so happens that there are only 2 unique values. In addition, if it was categorical, it would make more sense to make it a whole number rather than a decimal.

# %% [markdown]
# #### (m)

# %% [markdown]
# The fetal_health variable is ordinal because it goes from least severe to most severe. This gives meaning to the order of the variables.
#
# Histogram is nominal because there is no order. The asignment of left as -1, center as 0, and right at 1 is arbitrary. One could assign left as 1, right as 2, and center as 3 and it would result in a similar effect.

# %% [markdown]
# #### (n)

# %%
a,b,c = fetal_df['fetal_health'].value_counts()

print("Normal: " + str(a))
print("Suspect: " + str(b))
print("Pathological: " + str(c))
# Out:
# Normal: 1655
# Suspect: 295
# Pathological: 176

# %% [markdown]
# ## **Dirty Dataset**

# %%
# load the dirty dataset csv file into a pandas dataframe

fetal_dirty_df = pd.read_csv('fetal_health_dataset_dirty.csv')

# %% [markdown]
# ### Problem 1.2

# %% [markdown]
# #### (a)

# %%
print("Presence of missing values: ")
print(fetal_dirty_df.isna().sum().sum() > 0)
# Out:
# Presence of missing values:
# True

# %% [markdown]
# #### (b)

# %%
for col in fetal_dirty_df:
  if(fetal_dirty_df[col].isna().sum() != 0):
    print(col + " has nan values")
# Out:
# baseline value has nan values
# percentage_of_time_with_abnormal_long_term_variability has nan values
# histogram_max has nan values
# histogram_mode has nan values

# %% [markdown]
# The variables with Nan values are
#
#
# *   baseline_value
# *   percentage_of_time_with_abnormal_long_term_variability
# *   histogram_max
# *   histogram_mode

# %% [markdown]
# #### (c)

# %%
print("Number of missing samples: ")
print(fetal_dirty_df.isna().sum().sum())
# Out:
# Number of missing samples:
# 86

# %% [markdown]
# ### Problem 1.3

# %%
fetal_dirty_df.hist(figsize = [15,15])

#Baseline should not be less than 0 because it is bpm
for x in fetal_dirty_df['baseline value']:
  if(x < 0):
    fetal_dirty_df['baseline value'] = fetal_dirty_df['baseline value'].replace([x], np.nan)

#Percentage should be under 1 and over 0
for x in fetal_dirty_df['percentage_of_time_with_abnormal_long_term_variability']:
  if(x < 0 or x > 100):
    fetal_dirty_df['percentage_of_time_with_abnormal_long_term_variability'] = fetal_dirty_df['percentage_of_time_with_abnormal_long_term_variability'].replace([x], np.nan)

for x in fetal_dirty_df['abnormal_short_term_variability']:
  if(x < 0 or x > 100):
    fetal_dirty_df['abnormal_long_term_variability'] = fetal_dirty_df['abnormal_short_term_variability'].replace([x], no.nan)

display(fetal_dirty_df.loc[91:100,:])
# Out:
#      baseline value  accelerations  fetal_movement  uterine_contractions  \
# 91            148.0          0.000           0.000                 0.000
# 92            148.0          0.000           0.003                 0.000
# 93              NaN          0.000           0.000                 0.000
# 94            148.0          0.000           0.005                 0.002
# 95            148.0          0.000           0.000                 0.000
# 96            148.0          0.000           0.000                 0.000
# 97            148.0          0.000           0.001                 0.000
# 98            148.0          0.000           0.001                 0.000
# 99            125.0          0.010           0.007                 0.002
# 100           125.0          0.005           0.000                 0.002
#
#      light_decelerations  severe_decelerations  prolongued_decelerations  \
# 91                 0.000                   0.0                       0.0
# ...

# %% [markdown]
# First, I looked at the histograms to see what values had outliers. For the data that had outliers, I looked at what the data was. For example, baseline has an outlier that was negative, but histogram_variance has an outlier that is just larger than most of the data. The former case made no sense, so I altered the data such that baseline value was greater than 0. This is because baseline value is the bpm so it must be over zero. However, in most examples, the outliers were unlikely but realistic numbers so I left them alone. I also made sure that the percentage values are within 0 to 100.

# %% [markdown]
# ### Problem 1.4

# %%
#Commented coded is for comparing old and new means and variances.

#oldMean = fetal_dirty_df.mean()
#oldVar = fetal_dirty_df.var()


fetal_dirty_df.loc[:, ~fetal_dirty_df.columns.isin(['histogram_tendency', 'fetal_health'])] = \
sps.zscore(fetal_dirty_df.loc[:, ~fetal_dirty_df.columns.isin(['histogram_tendency', 'fetal_health'])], nan_policy = 'omit')

#newMean = fetal_dirty_df.mean()
#newVar = fetal_dirty_df.var()

#This is for printing to see the mean turn to zero and the variance turn to one.
#for col in fetal_dirty_df:
#  print(col + ' Old Mean: {}; Old Var: {}'.format(oldMean[col],oldVar[col]))
#  print(col + ' New Mean: {}; New Var: {}'.format(newMean[col],newVar[col]))


fetal_dirty_df.head(20)
# Out:
#     baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0        -1.351086      -0.822388       -0.203210             -1.482465
# 1        -0.131067       0.730133       -0.203210              0.554627
# 2        -0.029399      -0.046128       -0.203210              1.233657
# 3         0.072269      -0.046128       -0.203210              1.233657
# 4        -0.131067       0.988886       -0.203210              1.233657
# 5         0.072269      -0.563635       -0.203210              1.912687
# 6         0.072269      -0.563635       -0.203210              2.931233
# 7        -1.147750      -0.822388       -0.203210             -1.482465
# 8        -1.147750      -0.822388       -0.203210             -0.803434
# 9        -1.147750      -0.822388       -0.203210             -0.463919
# 10        1.800629      -0.822388       -0.203210             -1.142949
# 11        1.698961      -0.822388       -0.203210             -1.142949
# ...

# %% [markdown]
# ### Problem 1.5

# %%
colMedian = fetal_dirty_df.median()
fetal_dirty_df = fetal_dirty_df.fillna(colMedian)

totalNan = 0
for col in fetal_dirty_df:
  totalNan = totalNan + fetal_dirty_df[col].isna().sum()
print('Total number of Nan: '+ str(totalNan))
# Out:
# Total number of Nan: 0

# %% [markdown]
# ### Problem 1.6

# %%
fetal_dirty_df = pd.get_dummies(fetal_dirty_df, columns = ['fetal_health'])
fetal_dirty_df = fetal_dirty_df.rename(columns = {'fetal_health_1':'normal', 'fetal_health_2':'suspect', 'fetal_health_3':'pathological'})

display(fetal_dirty_df)

fetal_dirty_df.to_csv('fetal_health_dataset_processed.csv', index = False)
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0          -1.351086      -0.822388       -0.203210             -1.482465
# 1          -0.131067       0.730133       -0.203210              0.554627
# 2          -0.029399      -0.046128       -0.203210              1.233657
# 3           0.072269      -0.046128       -0.203210              1.233657
# 4          -0.131067       0.988886       -0.203210              1.233657
# ...              ...            ...             ...                   ...
# 2121        0.682278      -0.822388       -0.203210              0.894142
# 2122        0.682278      -0.563635       -0.203210              0.894142
# 2123        0.682278      -0.563635       -0.203210              0.894142
# 2124        0.682278      -0.563635       -0.203210              0.554627
# 2125        0.885615      -0.304881       -0.160342              1.233657
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# ...

# %% [markdown]
# # **2. Heart Failure Prediction Dataset**

# %% [markdown]
# ## Problem 2.1

# %%
# load the dataset csv file into a pandas dataframe

heart_df = pd.read_csv('heart_failure_dataset.csv')

# %% [markdown]
# ### (a)

# %% [markdown]
# This is a supervised learning task because there is a dependent feature. This feature specifically is death event. The purpose of this dataset isi meant to predict if a patient will die. Since the datasamples have information about if they are dead or not, this makes the task supervised.

# %% [markdown]
# ### (b)

# %%
heart_df.axes
heart_df.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %% [markdown]
# ### (c)

# %%
heart_df.head(10)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
# 5  90.0        1                        47         0                 40
# 6  75.0        1                       246         0                 15
# 7  60.0        1                       315         1                 60
# 8  65.0        0                       157         0                 65
# 9  80.0        1                       123         0                 35
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# ...

# %% [markdown]
# ### (d)

# %%
print('{} Rows\n{} Columns'.format(*heart_df.shape))
# Out:
# 299 Rows
# 13 Columns

# %% [markdown]
# ### (e)

# %% [markdown]
# There is a total of 299 data samples in this dataset.

# %% [markdown]
# ### (f)

# %% [markdown]
# There are 12 independent variables in this dataset.
#
#
#
# *   Age
# *   Anaemia
# *   creatine_phosphokinase
# *   diabetes
# *   ejection_fraction
# *   high_blood_pressure
# *   platelets
# *   serum_creatinine
# *   serum_sodium
# *   sex
# *   smoking
# *   time

# %% [markdown]
# ### (g)

# %% [markdown]
# There is one dependent variable in this data set. It is DEATH_EVENT

# %% [markdown]
# ### (h)

# %% [markdown]
# n would be 299 and p would be 12

# %% [markdown]
# ### (i)

# %% [markdown]
# n would be 299 and m would be 1

# %% [markdown]
# ### (j)

# %%
for col in heart_df:
  print(col + " " + str(pd.unique(heart_df[col])))

heart_df.hist(figsize = [15,15])
# Out:
# age [75.    55.    65.    50.    90.    60.    80.    62.    45.    49.
#  82.    87.    70.    48.    68.    53.    95.    58.    94.    85.
#  69.    72.    51.    57.    42.    41.    67.    79.    59.    44.
#  63.    86.    66.    43.    46.    61.    81.    52.    64.    40.
#  60.667 73.    77.    78.    54.    47.    56.   ]
# anaemia [0 1]
# creatinine_phosphokinase [ 582 7861  146  111  160   47  246  315  157  123   81  231  981  168
#    80  379  149  125   52  128  220   63  148  112  122   60   70   23
#   249  159   94  855 2656  235  124  571  127  588 1380  553  129  577
#    91 3964   69  260  371   75  607  789  364 7702  318  109   68  250
#   110  161  113 5882  224   92  102  203  336   76   55  280   78   84
#   115   66  897  154  144  133  514   59  156   61  305  898 5209   53
#   328  748 1876  936  292  369  143  754  400   96  737  358  200  248
#   270 1808 1082  719  193 4540  646  281 1548  805  291  482  943  185
# ...

# %% [markdown]
# *   Anaemia
# *   Diabetes
# *   high_blood_pressure
# *   sex
# *   smoking
# *   DEATH_EVENT

# %% [markdown]
# ### (k)

# %% [markdown]
# Binary encoding is used because it is either one or the other. In this case it is either 0 or 1.

# %% [markdown]
# ### (l)

# %%
#This is boolean, so 0 is alive and 1 is dead
deathSeries = heart_df['DEATH_EVENT'].value_counts()
print("Alive: " + str(deathSeries[0]))
print("Deceased: " + str(deathSeries[1]))
# Out:
# Alive: 203
# Deceased: 96

# %% [markdown]
# ### (m)

# %%
#This is binary so 0 can be male and 1 can be female or other way around
genderSeries = heart_df['sex'].value_counts()
print("Women: " + str(genderSeries[0]))
print("Men: " + str(genderSeries[1]))
# Out:
# Women: 105
# Men: 194

# %% [markdown]
# ### (n)

# %%
#Boolean, so 0 is non-smoker and 1 is smoker
smokerSeries = heart_df['smoking'].value_counts()
print("Non-smoker: " + str(smokerSeries[0]))
print("Smoker: " + str(smokerSeries[1]))
# Out:
# Non-smoker: 203
# Smoker: 96

# %% [markdown]
# ## Problem 2.2

# %%
heart_df.hist(figsize = [15,15])

heart_df['serum_sodium'] = heart_df['serum_sodium'].replace([113,116], np.nan)

# %% [markdown]
# *   Age:
#   The max age in this data set is 95. While this is old, this is not impossible to reach. The minimum age is above 0, so this section will remain unaltered
# *   Creatinine_phosphocinase
#   The 2 maxes here are 7861 mcg/L and 7702 mcg/L. These are almost very high levels, however upon further research, these are acceptably high. This means this category will remain unaltered.
# *   ejection_fraction
#   This is a percentage. No value goes below zero or above 100 so it will remain unaltered. In addition, upon further research, the normal amount is 50%-75% and low values of 10%-20% are normal among heart failure patients.
# *   platelets
#   There are no outliers here to investigate. This means this will remain unaltered
# *   Serum Creatinine
#   The max here is 9.4. This is not much different from the second highest 9.0. This indicates that this data is ok, so it will remain unaltered
# *   Serum Sodium
#   The minimum here is an outlier. It is a minimum of 113 mEq/L. Upon further research, dangerously low levels of serum sodium occur below values of 125. The second lowest value of serum sodium is 116, and the third lowest is 121. While 121 is realistically low, 113 and 116 seems too low to be survivable. For this reason, they will be removed.
#
# *   Time
#   There is no negative time here, so it will remain unaltered

# %% [markdown]
# ## Problem 2.3

# %%
#Commented coded is for comparing old and new means and variances.

#oldMean = heart_df.mean()
#oldVar = heart_df.var()

categoryColumns = ['anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking', 'DEATH_EVENT']
heart_df.loc[:, ~heart_df.columns.isin(categoryColumns)] = \
sps.zscore(heart_df.loc[:, ~heart_df.columns.isin(categoryColumns)], nan_policy = 'omit')

#newMean = heart_df.mean()
#newVar = heart_df.var()

#This is for printing to see the mean turn to zero and the variance turn to one.
#for col in heart_df:
#  print(col + ' Old Mean: {}; Old Var: {}'.format(oldMean[col],oldVar[col]))
#  print(col + ' New Mean: {}; New Var: {}'.format(newMean[col],newVar[col]))

heart_df.head(20)
# Out:
#          age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0   1.192945        0                  0.000166         0          -1.530560
# 1  -0.491279        0                  7.514640         0          -0.007077
# 2   0.350833        0                 -0.449939         0          -1.530560
# 3  -0.912335        1                 -0.486071         0          -1.530560
# 4   0.350833        1                 -0.435486         1          -1.530560
# 5   2.456114        1                 -0.552141         0           0.162199
# 6   1.192945        1                 -0.346704         0          -1.953749
# 7  -0.070223        1                 -0.275472         1           1.854958
# 8   0.350833        0                 -0.438583         0           2.278147
# 9   1.614001        1                 -0.473683         0          -0.260991
# 10  1.192945        1                 -0.517041         0          -0.007077
# ...

# %% [markdown]
# ## Problem 2.4

# %%
oneHot = pd.get_dummies(heart_df, columns = ['DEATH_EVENT'])
oneHot = oneHot.rename(columns = {'DEATH_EVENT_0':'alive', 'DEATH_EVENT_1':'deceased'})


oneHot.to_csv('heart_failure_dataset_processed.csv', index = False)

# %% [markdown]
# ## Problem 2.5

# %%
heart_df.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045799  0.048775                  0.070794
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# ...

# %% [markdown]
# ### (a)

# %% [markdown]
# The two other variables with the most positive correlation with DEATH_EVENT are
#
#
# 1.   serum_creatinine
# 2.   age
#
# Obviously DEATH_EVENT has the highest correlation with itself, but this is an uninteresting result since DEATH_EVENT equals itself.

# %% [markdown]
# ### (b)

# %% [markdown]
# The two variables with the most negative correlation with DEATH_EVENT are
#
#
# 1.   Time
# 2.   ejection_fraction

# %% [markdown]
# ### (c)

# %% [markdown]
# This makes sense because as age increases a person is more likely to pass away. This explains why the correlation is high. The value of DEATH_EVENT goes up to 1 when a person dies and a higher age is more likely to die.

# %% [markdown]
# ### (d)

# %% [markdown]
# It is logical that the two most negatively correlated variables with DEATH_EVENT, Time and ejection_fraction, because of how they related to DEATH_EVENT. In the case of time, its is the follow-up period. The longer the period, the less likely of a DEATH_EVENT. In the case of ejection_fraction, this is the percent of blood leaving the heart at each contraciton. Heart failure is the heart not pumping enough blood, so it makes sense that the more blood that is pumped the less likely of death. This explains the negative correlation.
